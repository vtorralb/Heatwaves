# %%
# connect to the service: 
import requests

response = requests.get('http://127.0.0.1:5000/wps?service=wps&request=getcapabilities')
print(response.text)
# Out:
# <?xml version="1.0" encoding="UTF-8"?>
# <!-- PyWPS 4.5.2 -->
# <wps:Capabilities service="WPS" version="1.0.0" xml:lang="en-US" xmlns:xlink="http://www.w3.org/1999/xlink" xmlns:wps="http://www.opengis.net/wps/1.0.0" xmlns:ows="http://www.opengis.net/ows/1.1" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xsi:schemaLocation="http://www.opengis.net/wps/1.0.0 ../wpsGetCapabilities_response.xsd" updateSequence="1">
#     <ows:ServiceIdentification>
#         <ows:Title>owl</ows:Title>
#         <ows:Abstract>Heatwave magnitude index and warm nights</ows:Abstract>
#         <ows:Keywords>
#         <ows:Keyword>PyWPS</ows:Keyword>
#         <ows:Keyword> WPS</ows:Keyword>
#         <ows:Keyword> OGC</ows:Keyword>
#         <ows:Keyword> processing</ows:Keyword>
#         <ows:Keyword> birdhouse</ows:Keyword>
#         <ows:Keyword> owl</ows:Keyword>
#         <ows:Keyword> demo</ows:Keyword>
#             <ows:Type codeSpace="ISOTC211/19115">theme</ows:Type>
# ...

# %%
response = requests.get('http://127.0.0.1:5000/wps?service=wps&version=1.0.0&request=describeprocess&identifier=HWs_detection')
print(response.text)
# Out:
# <?xml version="1.0" encoding="UTF-8"?>
# <!-- PyWPS 4.5.2 -->
# <wps:ProcessDescriptions xmlns:wps="http://www.opengis.net/wps/1.0.0" xmlns:ows="http://www.opengis.net/ows/1.1" xmlns:xlink="http://www.w3.org/1999/xlink" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xsi:schemaLocation="http://www.opengis.net/wps/1.0.0 ../wpsDescribeProcess_response.xsd" service="WPS" version="1.0.0" xml:lang="en-US">
#     <ProcessDescription wps:processVersion="0.1.0" storeSupported="true" statusSupported="true">
#         <ows:Identifier>HWs_detection</ows:Identifier>
#         <ows:Title>HWs_detection</ows:Title>
#         <ows:Abstract>AI-enhanced climate service to detect Heatwaves in climate datasets.</ows:Abstract>
#         <ows:Metadata xlink:title="HW Detection" xlink:type="simple"
#         />
#         <DataInputs>
#             <Input minOccurs="1" maxOccurs="1">
#                 <ows:Identifier>dataset</ows:Identifier>
# ...

# %%
# dataset = 'https://nextcloud.dkrz.de/s/FXoq6ixE54iBfgo/download'
dataset = 'http://esgf3.dkrz.de/thredds/fileServer/cmip6/ScenarioMIP/DKRZ/MPI-ESM1-2-HR/ssp126/r1i1p1f1/Ofx/areacello/gn/v20190710/areacello_Ofx_MPI-ESM1-2-HR_ssp126_r1i1p1f1_gn.nc'
response = requests.get(f'http://127.0.0.1:5000/wps?service=wps&version=1.0.0&request=execute&identifier=HWs_detection&datainputs=dataset=@xlink:href={dataset}')
print(response.text)
# Out:
# <?xml version="1.0" encoding="UTF-8"?>
# <wps:ExecuteResponse xmlns:wps="http://www.opengis.net/wps/1.0.0" xmlns:ows="http://www.opengis.net/ows/1.1" xmlns:xlink="http://www.w3.org/1999/xlink" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xsi:schemaLocation="http://www.opengis.net/wps/1.0.0 ../wpsExecute_response.xsd" service="WPS" version="1.0.0" xml:lang="en-US" serviceInstance="http://localhost:5000/wps?request=GetCapabilities&amp;amp;service=WPS" statusLocation="">
#     <wps:Process wps:processVersion="0.1.0">
#         <ows:Identifier>HWs_detection</ows:Identifier>
#         <ows:Title>HWs_detection</ows:Title>
#         <ows:Abstract>AI-enhanced climate service to detect Heatwaves in climate datasets.</ows:Abstract>
# 	</wps:Process>
#     <wps:Status creationTime="2022-08-17T08:00:29Z">
#         <wps:ProcessSucceeded>PyWPS Process HWs_detection finished</wps:ProcessSucceeded>
# 	</wps:Status>
# 	<wps:ProcessOutputs>
# 		<wps:Output>
# ...

# %%
from birdy import WPSClient

# %%
# owl = WPSClient(url='http://localhost:5000/wps')
owl_i = WPSClient(url='http://localhost:5000/wps', progress=True)
# Out:
# Traceback (most recent call last):
#
#   File ~/mambaforge/envs/heatwaves/lib/python3.10/site-packages/IPython/core/interactiveshell.py:3398 in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   Input In [6] in <cell line: 2>
#     owl_i = WPSClient(url='http://localhost:5000/wps', progress=True)
#
#   File ~/mambaforge/envs/heatwaves/lib/python3.10/site-packages/birdy/client/base.py:134 in __init__
#     self._wps.getcapabilities(xml=caps_xml)
#
#   File ~/mambaforge/envs/heatwaves/lib/python3.10/site-packages/owslib/wps.py:275 in getcapabilities
#     self._capabilities = reader.readFromUrl(
#
#   File ~/mambaforge/envs/heatwaves/lib/python3.10/site-packages/owslib/wps.py:552 in readFromUrl
#     return self._readFromUrl(url,
#
#   File ~/mambaforge/envs/heatwaves/lib/python3.10/site-packages/owslib/wps.py:512 in _readFromUrl
#     return etree.fromstring(u.read())
#
#   File src/lxml/etree.pyx:3254 in lxml.etree.fromstring
#
# ...
